# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\shubh\\ML course\\linear regrassion\\advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df['total_spend'] = df['TV'] + df['Radio'] + df['Newspaper']

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3   12.0        132.4
# 3  151.5   41.3       58.5   16.5        251.3
# 4  180.8   10.8       58.4   17.9        250.0

# %%
sns.scatterplot(data=df,x='total_spend',y='Sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='Sales'>

# %%
sns.regplot(data=df,x='total_spend',y='Sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='Sales'>

# %%
X = df['total_spend']
y = df['Sales']

# %%
#help(np.polyfit)

# %%
#np.polyfix
"""
np polyfix function return 
y = mx + c
y = B1x + c
i.e it give the beta coffient
"""
# Out:
# '\nnp polyfix function return \ny = mx + c\ny = B1x + c\ni.e it give the beta coffient\n'

# %%
np.polyfit(X,y,deg =1)
# it give the value B1= 0.052 and B0= 4.57 which is  beta value
# Out:
# array([0.0525585, 4.573573 ])

# %%
potentail_spend = np.linspace(0,500,100)

# %%
#y = B1x + B0
predicated_sales = 0.0525585*potentail_spend + 4.573573

# %%
sns.scatterplot(x='total_spend',y='Sales',data=df)
plt.plot(potentail_spend,predicated_sales, color='red')

# %%
# lest try slove some probelm
# how musch the sale if spen =200
spend = 200
predicated_sales = 0.0525585*200 + 4.573573

# %%
predicated_sales
# == by seeing graph we can that if you spend 200 total_spend than sales is 15 or something
# Out:
# 15.085272999999999
